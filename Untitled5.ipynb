# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([0,1,2,3,4,5])
y=np.array([0,8,12,20,26,38])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1=np.array([1,1,12,12,1])
y1=np.array([1,7,7,1,1])
x2=np.array([1,12])
y2=np.array([3,3])
x3=np.array([1,12])
y3=np.array([5,5])


x16=np.array([1,1,12,12])
y16=np.array([5,7,7,5])
x17=np.array([1,1,12,12])
y17=np.array([1,3,3,1])
x18=np.array([2])
y18=np.array([6])
x19=np.array([2.5])
y19=np.array([6])
x4=np.array([5])
y4=np.array([6.5])
x5=np.array([4.5])
y5=np.array([6.5])
x6=np.array([4])
y6=np.array([5])
x7=np.array([5])
y7=np.array([6.1])
x8=np.array([4])
y8=np.array(6.1)
x9=np.array([3.5])
y9=np.array([6.1])
x10=np.array([4.5])
y10=np.array([6.1])
x11=np.array([5])
y11=np.array([5.7])
x12=np.array([4.5])
y12=np.array([5.7])
x13=np.array([4])
y13=np.array([5.7])
x14=np.array([3.5])
y14=np.array([5.7])
x15=np.array([3])
y15=np.array([5.7])

plt.fill(x16,y16,color='#0099B5')
plt.fill(x17,y17,color='#1EB53A')
plt.plot(x16,y16)
plt.plot(x18,y18,ms=45,marker='o',color='white')
plt.plot(x19,y19,ms=45,marker='o',color='#0099B5')

plt.plot(x17,y17)

plt.plot(x4,y4,'*',x5,y5,'*',x7,y7,'*',x8,y8,'*',x9,y9,'*',x10,y10,'*',x11,y11,'*',x12,y12,'*',x13,y13,'*',x14,y14,'*',x15,y15,'*',color='white')

plt.plot(x1,y1)

plt.plot(x2,y2,y3,color='#CE1126')
plt.show()
